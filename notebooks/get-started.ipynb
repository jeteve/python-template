# %%
print("Hello jupiter")
# Out:
# Hello jupiter

# %%
import plotly.graph_objects as go
import numpy as np

# Setup coordinates
r = np.linspace(0, 10, 50)  # Rarity 0 = COMMON , 10 = RARE
x = np.linspace(0, 10, 50)  # Complexity 0 = SIMPLE , 10 = COMPLEX
R, X = np.meshgrid(r, x)

# 1. Prompting: Decreases as Commonality (C) increases
Z_prompt = ( R + ( X * R / 10 ) ) / 2

# 2. Coding: Linear on Complexity (X), drops to 0 at Commonality > 8
Z_code = np.where(R >= 2, X, 0)

r_line = np.linspace(2, 10, 100)
x_line = (10 * r_line) / (20 - r_line)
z_line = x_line # Since Z_code = X at intersection

fig = go.Figure(data=[
    go.Surface(z=Z_prompt, x=c, y=x, name="Prompting", colorscale="Plasma", opacity=0.8 ),
    go.Surface(z=Z_code, x=c, y=x, name="Coding", colorscale='Viridis', opacity=0.8 )
])

# HIGHLIGHT: The Intersection Curve
fig.add_trace(go.Scatter3d(
    x=r_line, y=x_line, z=z_line,
    mode='lines',
    line=dict(color='red', width=12),
    name='Optimal Boundary'
))

fig.update_layout(title='Effort Landscape', 

    width=1200,     # Adjust based on your screen size
    height=1000,     # Vertical height of the viewport
    margin=dict(l=0, r=0, b=0, t=40), # Minimize margins to maximize plot area
    scene=dict(
    xaxis_title='Rarity', yaxis_title='Complexity', zaxis_title='Effort'
))
fig.show()
